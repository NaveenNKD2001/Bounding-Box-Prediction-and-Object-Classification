# %%
import numpy as np
import pandas as pd
import random

import os
from glob import glob

import xml.etree.ElementTree as et
import cv2

from sklearn.model_selection import train_test_split
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\navee\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
xml=glob('Object_detection_dataset\\annotations\\*.xml')

# %%
xml[0]
# Out:
# 'Object_detection_dataset\\annotations\\road0.xml'

# %%
len(xml)
# Out:
# 877

# %%
annotations_list=[]

for i in xml:
    
    root=et.parse(i).getroot()
    
    image_name=root.find('filename').text
    image_path=os.path.join('Object_detection_dataset\\images',image_name)
    
    label=root.find('object/name').text
    
    width=int(root.find('size/width').text)
    height=int(root.find('size/height').text)
    
    xmin=int(root.find('object/bndbox/xmin').text)
    ymin=int(root.find('object/bndbox/ymin').text)
    xmax=int(root.find('object/bndbox/xmax').text)
    ymax=int(root.find('object/bndbox/ymax').text)
    
    annotations_list.append([image_path,label,width,height,xmin,ymin,xmax,ymax])

# %%
cols=['image_path','label','width','height','xmin','ymin','xmax','ymax']
df=pd.DataFrame(annotations_list,columns=cols)

# %%
df.head()
# Out:
#                                     image_path         label  width  height  \
# 0    Object_detection_dataset\images\road0.png  trafficlight    267     400
# 1    Object_detection_dataset\images\road1.png  trafficlight    400     283
# 2   Object_detection_dataset\images\road10.png  trafficlight    400     267
# 3  Object_detection_dataset\images\road100.png    speedlimit    400     385
# 4  Object_detection_dataset\images\road101.png    speedlimit    400     200
#
#    xmin  ymin  xmax  ymax
# 0    98    62   208   232
# 1   154    63   258   281
# 2   106     3   244   263
# 3    35     5   363   326
# 4   195     7   392   194

# %%
df['label'].unique()
# Out:
# array(['trafficlight', 'speedlimit', 'crosswalk', 'stop'], dtype=object)

# %%
dictionary={'trafficlight':0,'speedlimit':1,'crosswalk':2,'stop':3}

df['label']=[dictionary[i] for i in df['label']]

# %%
df.head()
# Out:
#                                     image_path  label  width  height  xmin  \
# 0    Object_detection_dataset\images\road0.png      0    267     400    98
# 1    Object_detection_dataset\images\road1.png      0    400     283   154
# 2   Object_detection_dataset\images\road10.png      0    400     267   106
# 3  Object_detection_dataset\images\road100.png      1    400     385    35
# 4  Object_detection_dataset\images\road101.png      1    400     200   195
#
#    ymin  xmax  ymax
# 0    62   208   232
# 1    63   258   281
# 2     3   244   263
# 3     5   363   326
# 4     7   392   194

# %%
max(df['width'].values)
# Out:
# 400

# %%
max(df['height'].values)
# Out:
# 400

# %%
df['r_width']=250
df['r_height']=250

df['r_xmin']=(df['r_width']/df['width'])*df['xmin']
df['r_ymin']=(df['r_height']/df['height'])*df['ymin']
df['r_xmax']=(df['r_width']/df['width'])*df['xmax']
df['r_ymax']=(df['r_height']/df['height'])*df['ymax']

# %%
df.head()
# Out:
#                                     image_path  label  width  height  xmin  \
# 0    Object_detection_dataset\images\road0.png      0    267     400    98
# 1    Object_detection_dataset\images\road1.png      0    400     283   154
# 2   Object_detection_dataset\images\road10.png      0    400     267   106
# 3  Object_detection_dataset\images\road100.png      1    400     385    35
# 4  Object_detection_dataset\images\road101.png      1    400     200   195
#
#    ymin  xmax  ymax  r_width  r_height    r_xmin     r_ymin      r_xmax  \
# 0    62   208   232      250       250   91.7603  38.750000  194.756554
# 1    63   258   281      250       250   96.2500  55.653710  161.250000
# 2     3   244   263      250       250   66.2500   2.808989  152.500000
# 3     5   363   326      250       250   21.8750   3.246753  226.875000
# 4     7   392   194      250       250  121.8750   8.750000  245.000000
#
#        r_ymax
# 0  145.000000
# 1  248.233216
# 2  246.254682
# 3  211.688312
# 4  242.500000

# %%
df['r_xmin']=[int(round(i)) for i in df['r_xmin'].values]
df['r_ymin']=[int(round(i)) for i in df['r_ymin'].values]
df['r_xmax']=[int(round(i)) for i in df['r_xmax'].values]
df['r_ymax']=[int(round(i)) for i in df['r_ymax'].values]

df['new_bb_coordinates']=df[['r_xmin','r_ymin','r_xmax','r_ymax']].values.tolist()

# %%
df.head()
# Out:
#                                     image_path  label  width  height  xmin  \
# 0    Object_detection_dataset\images\road0.png      0    267     400    98
# 1    Object_detection_dataset\images\road1.png      0    400     283   154
# 2   Object_detection_dataset\images\road10.png      0    400     267   106
# 3  Object_detection_dataset\images\road100.png      1    400     385    35
# 4  Object_detection_dataset\images\road101.png      1    400     200   195
#
#    ymin  xmax  ymax  r_width  r_height  r_xmin  r_ymin  r_xmax  r_ymax  \
# 0    62   208   232      250       250      92      39     195     145
# 1    63   258   281      250       250      96      56     161     248
# 2     3   244   263      250       250      66       3     152     246
# 3     5   363   326      250       250      22       3     227     212
# 4     7   392   194      250       250     122       9     245     242
#
#    new_bb_coordinates
# 0  [92, 39, 195, 145]
# 1  [96, 56, 161, 248]
# 2   [66, 3, 152, 246]
# 3   [22, 3, 227, 212]
# 4  [122, 9, 245, 242]

# %%
df.loc[140:150]
# Out:
#                                       image_path  label  width  height  xmin  \
# 140  Object_detection_dataset\images\road224.png      1    300     400   146
# 141  Object_detection_dataset\images\road225.png      1    300     400   162
# 142  Object_detection_dataset\images\road226.png      1    300     400   134
# 143  Object_detection_dataset\images\road227.png      1    300     400   141
# 144  Object_detection_dataset\images\road228.png      1    300     400   156
# 145  Object_detection_dataset\images\road229.png      1    300     400   120
# 146   Object_detection_dataset\images\road23.png      0    266     400   216
# 147  Object_detection_dataset\images\road230.png      1    300     400   124
# 148  Object_detection_dataset\images\road231.png      1    300     400   128
# 149  Object_detection_dataset\images\road232.png      1    300     400   127
# 150  Object_detection_dataset\images\road233.png      1    300     400   124
#
#      ymin  xmax  ymax  r_width  r_height  r_xmin  r_ymin  r_xmax  r_ymax  \
# 140   192   159   205      250       250     122     120     132     128
# 141   212   172   222      250       250     135     132     143     139
# 142   175   156   197      250       250     112     109     130     123
# 143   181   153   193      250       250     118     113     128     121
# 144   179   172   196      250       250     130     112     143     122
# 145   171   140   191      250       250     100     107     117     119
# 146   126   242   179      250       250     203      79     227     112
# 147   193   138   207      250       250     103     121     115     129
# 148   195   149   216      250       250     107     122     124     135
# 149   221   142   234      250       250     106     138     118     146
# 150   194   143   214      250       250     103     121     119     134
#
#        new_bb_coordinates
# 140  [122, 120, 132, 128]
# 141  [135, 132, 143, 139]
# 142  [112, 109, 130, 123]
# 143  [118, 113, 128, 121]
# 144  [130, 112, 143, 122]
# 145  [100, 107, 117, 119]
# 146   [203, 79, 227, 112]
# 147  [103, 121, 115, 129]
# 148  [107, 122, 124, 135]
# 149  [106, 138, 118, 146]
# 150  [103, 121, 119, 134]

# %%
def resize_save(old_image_path):
    img=cv2.resize(cv2.imread(old_image_path),(250,250))
    new_image_path=os.path.join('Object_detection_dataset\\images_resized',os.path.split(old_image_path)[1])
    
    cv2.imwrite(new_image_path,img)
    
    return new_image_path

# %%
df['new_image_path']=[resize_save(i) for i in df['image_path'].values]

# %%
df.head()
# Out:
#                                     image_path  label  width  height  xmin  \
# 0    Object_detection_dataset\images\road0.png      0    267     400    98
# 1    Object_detection_dataset\images\road1.png      0    400     283   154
# 2   Object_detection_dataset\images\road10.png      0    400     267   106
# 3  Object_detection_dataset\images\road100.png      1    400     385    35
# 4  Object_detection_dataset\images\road101.png      1    400     200   195
#
#    ymin  xmax  ymax  r_width  r_height  r_xmin  r_ymin  r_xmax  r_ymax  \
# 0    62   208   232      250       250      92      39     195     145
# 1    63   258   281      250       250      96      56     161     248
# 2     3   244   263      250       250      66       3     152     246
# 3     5   363   326      250       250      22       3     227     212
# 4     7   392   194      250       250     122       9     245     242
#
#    new_bb_coordinates                                     new_image_path
# 0  [92, 39, 195, 145]  Object_detection_dataset\images_resized\road0.png
# 1  [96, 56, 161, 248]  Object_detection_dataset\images_resized\road1.png
# 2   [66, 3, 152, 246]  Object_detection_dataset\images_resized\road10...
# 3   [22, 3, 227, 212]  Object_detection_dataset\images_resized\road10...
# 4  [122, 9, 245, 242]  Object_detection_dataset\images_resized\road10...

# %%
#flipping the image
def flip_image_bounding(image,bb,flip_code):
        
    flipped_image=cv2.flip(image,flip_code)
    
    if flip_code==1:
        bb[0],bb[2]=image.shape[1]-bb[2],image.shape[1]-bb[0]
    
    elif flip_code==0:
        bb[1],bb[3]=image.shape[0]-bb[3],image.shape[0]-bb[1]
    
    return flipped_image,bb


#rotating the image
def rotate_image_bounding(image,bb,angle):
    
    rotation_matrix=cv2.getRotationMatrix2D((image.shape[1]/2,image.shape[0]/2),angle,1)
    rotated_image=cv2.warpAffine(image,rotation_matrix,(image.shape[1],image.shape[0]))
    
    t=cv2.transform(np.array([[bb[0],bb[1]],[bb[2],bb[3]]]).reshape(-1,1,2),rotation_matrix)
    
  
    bb[0],bb[1]=t[0][0]
    bb[2],bb[3]=t[1][0]
    
    return rotated_image,bb


#performing the random crop
def random_crop(image,bb,crop_size):
    
    if image.shape[0]<crop_size[0] or image.shape[1]<crop_size[1]:
        return image,bb
    
    max_x=image.shape[1]-crop_size[1]
    max_y=image.shape[0]-crop_size[0]
    
    x=np.random.randint(0,max_x+1)
    y=np.random.randint(0,max_y+1)
    
    cropped_image=image[y:y+crop_size[0],x:x+crop_size[1]]
    
    bb[0]=max(0,bb[0]-x)
    bb[1]=max(0,bb[1]-y)
    bb[2]=min(crop_size[1],bb[2]-x)
    bb[3]=min(crop_size[0],bb[3]-x)
    
    return cropped_image,bb
              
              
#performing center crop
def center_crop(image,bb,crop_size):
    
              
    if image.shape[0]<crop_size[0] or image.shape[1]<crop_size[1]:
        return image,bb
    
    center_x=image.shape[1]//2
    center_y=image.shape[0]//2
              
    x=center_x-crop_size[1]//2
    y=center_y-crop_size[0]//2
              
    cropped_image=image[y:y+crop_size[0],x:x+crop_size[1]]
    
    bb[0]=max(0,bb[0]-x)
    bb[1]=max(0,bb[1]-y)
    bb[2]=min(crop_size[1],bb[2]-x)
    bb[3]=min(crop_size[0],bb[3]-y)
    
    return cropped_image,bb

# %%
def image_transformations(image_path,bb,flip=True,rotate=True,rcrop=True,ccrop=True):
    image=cv2.imread(image_path)
    w=image.shape[1]
    h=image.shape[0]
    
    if flip:
        code=np.random.choice([0, 1])
        image,bb=flip_image_bounding(image,bb,code)
    
    if rotate:
        ang=np.random.randint(1,360)
        image,bb=rotate_image_bounding(image,bb,ang)
        
    if rcrop:
        size=[224,224]
        image,bb=random_crop(image,bb,size)
        
    if ccrop:
        size=[224,224]
        image,bb=center_crop(image,bb,size)
        
    
    image=cv2.resize(image,(224,224))
    bb[0]=int(round((224/w)*bb[0]))
    bb[1]=int(round((224/h)*bb[1]))
    bb[2]=int(round((224/w)*bb[2]))
    bb[3]=int(round((224/h)*bb[3]))
    
    return image,bb

# %%
def normalize_image(image):
    image=tf.image.convert_image_dtype(image, tf.float32)
    n_image=image/255.0
    return n_image

# %%
x=df[['new_image_path','new_bb_coordinates']]
y=df[['label']]

# %%
df.loc[142]
# Out:
# image_path                  Object_detection_dataset\images\road226.png
# label                                                                 1
# width                                                               300
# height                                                              400
# xmin                                                                134
# ymin                                                                175
# xmax                                                                156
# ymax                                                                197
# r_width                                                             250
# r_height                                                            250
# r_xmin                                                              112
# r_ymin                                                              109
# r_xmax                                                              130
# r_ymax                                                              123
# new_bb_coordinates                                 [112, 109, 130, 123]
# new_image_path        Object_detection_dataset\images_resized\road22...
# Name: 142, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0,stratify=y)

# %%
def preprocess_image(image_path,bb,label,transforms):
    image=cv2.imread(image_path)
    
    if transforms:
        image,bb=image_transformations(image_path,bb,flip=np.random.choice([True,False]),rotate=np.random.choice([True,False]),rcrop=np.random.choice([True,False]),ccrop=np.random.choice([True,False]))
    
    n_image=normalize_image(image)
    
    return n_image,bb,label

# %%
train=[preprocess_image(i,j,k,transforms=True) for i,j,k in zip(x_train['new_image_path'],x_train['new_bb_coordinates'],y_train['label'])]
test=[preprocess_image(i,j,k,transforms=True) for i,j,k in zip(x_test['new_image_path'],x_test['new_bb_coordinates'],y_test['label'])]

# %%
train_images,train_bb,train_labels=zip(*train)
test_images,test_bb,test_labels=zip(*test)

# %%
train_images=np.array(train_images)
train_bb=np.array(train_bb)
train_labels=np.array(train_labels)

test_images=np.array(test_images)
test_bb=np.array(test_bb)
test_labels=np.array(test_labels)

# %%
image_input=tf.keras.layers.Input(shape=(224,224,3),name='image_input')

feature_extraction=tf.keras.layers.Conv2D(32,(3,3),activation='relu')(image_input)
feature_extraction=tf.keras.layers.MaxPool2D((2,2))(feature_extraction)
#feature_extraction=tf.keras.layers.Dropout(0.3)(feature_extraction)

fexture_extraction=tf.keras.layers.Conv2D(64,(3,3),activation='relu')(feature_extraction)
feature_extraction=tf.keras.layers.MaxPool2D((2,2))(feature_extraction)
#feature_extraction=tf.keras.layers.Dropout(0.3)(feature_extraction)

# fexture_extraction=tf.keras.layers.Conv2D(128,(3,3),activation='relu')(feature_extraction)
# feature_extraction=tf.keras.layers.MaxPool2D((2,2))(feature_extraction)
#feature_extraction=tf.keras.layers.Dropout(0.3)(feature_extraction)

# fexture_extraction=tf.keras.layers.Conv2D(256,(3,3),activation='relu')(feature_extraction)
# feature_extraction=tf.keras.layers.MaxPool2D((2,2))(feature_extraction)

feature_extraction=tf.keras.layers.Flatten()(feature_extraction)
# Out:
# WARNING:tensorflow:From C:\Users\navee\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\navee\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
#bb_output=tf.keras.layers.Dropout(0.3)(feature_extraction)
bb_output=tf.keras.layers.Dense(32,activation='relu')(feature_extraction)
#bb_output=tf.keras.layers.Dense(128,activation='relu')(bb_output)
# bb_output=tf.keras.layers.Dense(64,activation='relu')(bb_output)
bb_output=tf.keras.layers.Dense(4,activation='linear',name='bb_output')(bb_output)

# %%
#label_output=tf.keras.layers.Dropout(0.5)(feature_extraction)
label_output=tf.keras.layers.Dense(32,activation='relu')(feature_extraction)
#label_output=tf.keras.layers.Dense(128,activation='relu')(label_output)
# label_output=tf.keras.layers.Dense(64,activation='relu')(label_output)
label_output=tf.keras.layers.Dense(4,activation='softmax',name='label_output')(label_output)

# %%
model=tf.keras.models.Model(inputs=image_input,outputs=[bb_output,label_output])

# %%
model.compile(optimizer='adam',
             loss={'bb_output':'mse','label_output':'sparse_categorical_crossentropy'},
              metrics={'bb_output':'mae','label_output':'accuracy'})
# Out:
# WARNING:tensorflow:From C:\Users\navee\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(train_images,{'bb_output':train_bb,'label_output':train_labels},
         validation_data=[test_images,{'bb_output':test_bb,'label_output':test_labels}],
          epochs=10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\navee\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\navee\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 22/22 [==============================] - 5s 189ms/step - loss: 9721.8555 - bb_output_loss: 9720.7666 - label_output_loss: 1.0884 - bb_output_mae: 88.8966 - label_output_accuracy: 0.7461 - val_loss: 4436.9121 - val_bb_output_loss: 4435.9990 - val_label_output_loss: 0.9127 - val_bb_output_mae: 55.7637 - val_label_output_accuracy: 0.7443
# Epoch 2/10
# 22/22 [==============================] - 4s 173ms/step - loss: 2671.9646 - bb_output_loss: 2671.0581 - label_output_loss: 0.9067 - bb_output_mae: 41.1681 - label_output_accuracy: 0.7432 - val_loss: 1565.7886 - val_bb_output_loss: 1564.9073 - val_label_output_loss: 0.8812 - val_bb_output_mae: 31.3092 - val_label_output_accuracy: 0.7443
# Epoch 3/10
# 22/22 [==============================] - 4s 181ms/step - loss: 1653.7360 - bb_output_loss: 1652.8606 - label_output_loss: 0.8753 - bb_output_mae: 31.3756 - label_output_accuracy: 0.7432 - val_loss: 1591.9220 - val_bb_output_loss: 1590.9999 - val_label_output_loss: 0.9221 - val_bb_output_mae: 31.2348 - val_label_output_accuracy: 0.7443
# Epoch 4/10
# 22/22 [==============================] - 4s 188ms/step - loss: 1605.5905 - bb_output_loss: 1604.6837 - label_output_loss: 0.9067 - bb_output_mae: 30.9181 - label_output_accuracy: 0.7432 - val_loss: 1530.4789 - val_bb_output_loss: 1529.5226 - val_label_output_loss: 0.9564 - val_bb_output_mae: 30.7483 - val_label_output_accuracy: 0.7443
# Epoch 5/10
# 22/22 [==============================] - 4s 174ms/step - loss: 1606.4688 - bb_output_loss: 1605.5533 - label_output_loss: 0.9153 - bb_output_mae: 30.9056 - label_output_accuracy: 0.7432 - val_loss: 1534.1809 - val_bb_output_loss: 1533.2152 - val_label_output_loss: 0.9655 - val_bb_output_mae: 30.7768 - val_label_output_accuracy: 0.7443
# Epoch 6/10
# 22/22 [==============================] - 4s 168ms/step - loss: 1603.3101 - bb_output_loss: 1602.3944 - label_output_loss: 0.9155 - bb_output_mae: 30.8696 - label_output_accuracy: 0.7432 - val_loss: 1535.2628 - val_bb_output_loss: 1534.3827 - val_label_output_loss: 0.8801 - val_bb_output_mae: 30.8094 - val_label_output_accuracy: 0.7443
# Epoch 7/10
# 22/22 [==============================] - 4s 176ms/step - loss: 1600.6714 - bb_output_loss: 1599.8037 - label_output_loss: 0.8675 - bb_output_mae: 30.8731 - label_output_accuracy: 0.7432 - val_loss: 1536.8995 - val_bb_output_loss: 1536.0261 - val_label_output_loss: 0.8735 - val_bb_output_mae: 30.8289 - val_label_output_accuracy: 0.7443
# Epoch 8/10
# 22/22 [==============================] - 4s 181ms/step - loss: 1601.7174 - bb_output_loss: 1600.8575 - label_output_loss: 0.8595 - bb_output_mae: 30.8769 - label_output_accuracy: 0.7432 - val_loss: 1542.0375 - val_bb_output_loss: 1541.1891 - val_label_output_loss: 0.8484 - val_bb_output_mae: 30.8669 - val_label_output_accuracy: 0.7443
# Epoch 9/10
# 22/22 [==============================] - 4s 179ms/step - loss: 1607.9744 - bb_output_loss: 1607.0875 - label_output_loss: 0.8867 - bb_output_mae: 30.9441 - label_output_accuracy: 0.7432 - val_loss: 1537.4066 - val_bb_output_loss: 1536.5245 - val_label_output_loss: 0.8821 - val_bb_output_mae: 30.7889 - val_label_output_accuracy: 0.7443
# Epoch 10/10
# 22/22 [==============================] - 4s 167ms/step - loss: 1601.8351 - bb_output_loss: 1600.9675 - label_output_loss: 0.8676 - bb_output_mae: 30.8994 - label_output_accuracy: 0.7432 - val_loss: 1536.6328 - val_bb_output_loss: 1535.7401 - val_label_output_loss: 0.8926 - val_bb_output_mae: 30.7651 - val_label_output_accuracy: 0.7443

# %%
predictions=model.predict(test_images)
# Out:
# 6/6 [==============================] - 0s 36ms/step

# %%
predicted_boxes=predictions[0]

# %%
predicted_labels=np.argmax(predictions[1],axis=1)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
print("Accuracy is: ",accuracy_score(test_labels,predicted_labels))
print("Precision is: ",precision_score(test_labels,predicted_labels,average='weighted'))
print("Recall is: ",recall_score(test_labels,predicted_labels,average='weighted'))
print("F1 score is: ",f1_score(test_labels,predicted_labels,average='weighted'))
# Out:
# Accuracy is:  0.7443181818181818
# Precision is:  0.5540095557851239
# Recall is:  0.7443181818181818
# F1 score is:  0.6352161681966243
# C:\Users\navee\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
iou_scores=[]

def iou_score_calculator(bb1,bb2):
    
    area_1=(bb1[2]-bb1[0])*(bb1[3]-bb1[1])
    area_2=(bb2[2]-bb2[0])*(bb2[3]-bb2[1])
    
    x1=max(bb1[0],bb2[0])
    y1=max(bb1[1],bb2[1])
    x2=min(bb1[2],bb2[2])
    y2=min(bb1[3],bb2[3])
    
    if x2<x1 or y2<y1:
        iou_scores.append(0)
        return 0
    
    i=(x2-x1)*(y2-y1)
    u=area_1+area_2-i
    
    iou_scores.append(i/u)
    
    return 0

# %%
for bb1,bb2 in zip(test_bb,predicted_boxes):
    iou_score_calculator(bb1,bb2)

# %%
print("Average IOU score: ",sum(iou_scores)/len(iou_scores))
# Out:
# Average IOU score:  0.022397791039548334
